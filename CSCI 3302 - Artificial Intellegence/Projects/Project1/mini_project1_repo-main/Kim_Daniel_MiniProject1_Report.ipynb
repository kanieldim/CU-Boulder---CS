# %% [markdown]
# # Mini Project 1 Report

# %% [markdown]
# Your name: `Daniel Kim`

# %%
# %matplotlib inline
import math 
from curveFitting import one_dimensional_curve_fitting_test

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# - Attempt these problems only after you have finished and tested your implementation.
# - If you modify any of the python files, remember to "restart the kernel" or else the changes will not take effect.
# - We have provided 5 tests below. For each test, run it 5 different times and record the best solution/fitness for each trial along with the run time.
# - You will need to modify the code below, perhaps adding some nice print statements or adding your results to a table.

# %%
import timeit

start = timeit.default_timer()

one_dimensional_curve_fitting_test(lambda x: 0.2*math.exp(x/4.0) -  math.sin(2*x)  , (-10.0, 10.0), 25)

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# GA Returned Solution: cos((cos(x) + sin(x))) with fitness -8.1170086869097
# Time:  5.0229810000018915

# %%
import timeit

start = timeit.default_timer()

one_dimensional_curve_fitting_test(lambda x: math.sin(2*x) - math.cos(3*x-1) + 2*math.sin(x/2+1.0)  , (-15.0, 15.0), 60)

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# GA Returned Solution: sinh(cos((x * -0.5))) with fitness -74.94067199547153
# Time:  5.270990700002585

# %%
import timeit

start = timeit.default_timer()

one_dimensional_curve_fitting_test(lambda x: math.exp(math.sin(2*x)) - math.exp(math.cos(3*x))  , (-15.0, 15.0), 60)

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# GA Returned Solution: sin((cos(x) + (x + x + -0.5) + (x + -1.0))) with fitness -38.50222413307632
# Time:  5.214099299999361

# %%
import timeit

start = timeit.default_timer()

one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*x + 5.0 * math.sin(3*x) , (-15.0, 15.0), 60)

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# GA Returned Solution: (((x/1.0)/x - 0.5) + ((x - 0.5 + -2.5)/-2.5)) with fitness -1483.0461653276575
# Time:  5.429043299998739

# %%
import timeit

start = timeit.default_timer()

one_dimensional_curve_fitting_test(lambda x: 0.05*x**2 - 0.5*math.sqrt(x) + 5.0 * math.sin(3*x) , (0.0, 15.0), 30)

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# GA Returned Solution: (((x + -0.9845682340029906) * 0.49129549643388193) + -0.5) with fitness -438.01356479316286
# Time:  2.6370014999993145

# %% [markdown]
# `Put your table with results here!` You may [create a table using markdown](https://www.tablesgenerator.com/markdown_tables) (below) or print a nicely formatted table using a library such as Pandas.
#
# |   | Test 1  | Test 2   |  Test 3 |  Test 4 |  Test 5 |
# |---  |---  |---  |---  |---  |---  |
# |  Best Solution |  cos((cos(x) + sin(x))) |  sinh(cos((x * -0.5))) |  sin((cos(x) + (x + x + -0.5) + (x + -1.0))) |  (((x/1.0)/x - 0.5) + ((x - 0.5 + -2.5)/-2.5)) |  (((x + -0.9845682340029906) * 0.49129549643388193) + -0.5) |
# |  Best Fitness | -8.1170086869097  |  -74.94067199547153 |  -38.50222413307632 |  -1483.0461653276575 |  -438.01356479316286 |
# |  Time | 5.0229810000018915  |  5.270990700002585 |  5.214099299999361 |  5.429043299998739 |  2.6370014999993145 |

# %% [markdown]
# Write a brief analysis of your results. Some questions to answer:
# - Which problem ran the fastest? Why do you think this is the case?
# - Which problem ended with the highest fitness? Why do you think this is the case?
# - How similar were the running times across the 5 repetitions?
# - How similar were the final fitness scores across the 5 repetitions?
# - Was there anything else interesting in your results?

# %% [markdown]
# `Your answer here.`
#
# - Overall, without restarting the kernel again, the first 4 tests ran quick and smoothly, but before I run Test 5, I have to restart the kernel again in order to run smoothly. So that's why for Test 5, it only took 2.637800 seconds. Besides the problem that I have just mentioned, I believe that Test 1 ran the fastest because the parameters x_limits and n_data_points were lower compared to other tests.
#
# - Because of fewer data points and lambda fundtion, Test 1 ( one_dimensional_curve_fitting_test(lambda x: 0.2*math.exp(x/4.0) -  math.sin(2*x)  , (-10.0, 10.0), 25) ) finished with the highest fitness with -8.1170086869097
#
# - First 4 tests were pretty similar in terms of running times, but steadily getting slower each time. I believe that Test 5 should be different than the other tests because of the exponential dragging the run time.
#
# - All of the final fitness scores across the 5 repititions were all over the place. There were no patterns or had any relations to each other. Test 1 got the hightest and Test 4 got the lowest.
#
# - I just thought that the run time for Test 5 was interesting, even though I restarted the kernel before starting Test 5. Similar to Test 5, I restarted the kernel before running Test 1 and resulted with 5.022 seconds. This made me wonder if I answered the first bullet point wrong because technically, Test 5 was faster than Test 1.

# %% [markdown]
# ## Describe Your Implementation and Reflect

# %% [markdown]
# Some questions to answer in your write-up:
# - What was your strategy to solve this problem?
# - How did you structure your `GASolver` class?
# - What other files or methods did you change?
# - What was the most difficult part of the project?
# - What was something surprising you found?
#
# Please provide some elaboration with your answers. When describing your implementation, remember that we have not watched you solve this problem so you will need to give more details than you think is necessary.

# %% [markdown]
# `Your answer here.`
#
# - I simply followed the instructions and especially looked into the GAParams and crossOverOperators.py because GAParams gave me important information such as key words and the description, and I had a lot of trouble utilizing crossOverOperators in the run_ga_iterations function.
#
# - In order to sort top elite (top_k) easily in the end, I began with a while loop to create the self.pop. In the next step, I created a for loop in order to get fitness and weight array into the population array. I have also implimented a dictionary (dict) to set it equal to fitness_result array, so that I can sort the top elite with dictionary. After setting new_generation to sorted top elite (top_k), I was able to loop them to find the best fitness and the best solution.
#
# - I only looked at them to see what they can do, and I was concerned that I might change too much to run the tests with errors.
#
# - Even though they gave me a step by step instruction, I still had trouble with using the methods that you guys provided because I couldn't understand why I have to use these methods for. I really gave some good time to understand what I am trying to solve. In addition, since I understood the problem that I was facing, I had to improvise some of the steps in order to get what I needed such as implimenting GASolver class.
#
# - I found it interesting that the fitness score can vary, and how it gave the GA solutions in the result which seemed pretty complicated.

# %% [markdown]
# ## Going Above and Beyond

# %% [markdown]
# Describe the extra changes you implemented. Give some details, perhaps a short paragraph for each major change.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Describe the analysis you did and provide your results in the form of a figure or a table.

# %% [markdown]
# `Your answer here.`

# %% [markdown]
# Reflect on your work for this section. What was interesting, or what did you learn? A short paragraph here is fine.

# %% [markdown]
# `Your answer here.`
